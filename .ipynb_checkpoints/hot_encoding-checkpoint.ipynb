# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import Imputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %%
np.random.seed(0)
###### Read the data
train = pd.read_csv('original/train.csv')
train.sample(3)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 529  530          20       RL          NaN    32668   Pave   NaN      IR1
# 491  492          50       RL         79.0     9490   Pave   NaN      Reg
# 459  460          50       RL          NaN     7015   Pave   NaN      IR1
#
#     LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 529         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 491         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 459         Bnk    AllPub    ...            0    NaN    NaN         NaN
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 529       0      3   2007        WD         Alloca     200624
# 491       0      8   2006        WD         Normal     133000
# 459       0      7   2009        WD         Normal     110000
#
# [3 rows x 81 columns]

# %% [markdown]
# # Descide which variables to keep
# First I go through the whole list and decide which fields I will drop for further investigations...

# %%
columns_of_interest = ["LotFrontage", "LotArea", "Street", "Alley", "LotShape", "LandContour", "Utilities", "Utilities", "LotConfig", "LandSlope", "Condition1", "Condition2", "YearBuilt", "YearRemodAdd", "MoSold", "YrSold", "SaleType", "SaleCondition", "SalePrice"]
train = train[columns_of_interest]

# %%
train.sample(3)
# Out:
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 1453         90.0    17217   Pave   NaN      Reg         Lvl    AllPub
# 216          65.0     8450   Pave   NaN      Reg         Lvl    AllPub
# 1413         88.0    10994   Pave   NaN      IR1         Lvl    AllPub
#
#      Utilities LotConfig LandSlope Condition1 Condition2  YearBuilt  \
# 1453    AllPub    Inside       Gtl       Norm       Norm       2006
# 216     AllPub    Inside       Gtl       Norm       Norm       2004
# 1413    AllPub    Corner       Gtl       Norm       Norm       2005
#
#       YearRemodAdd  MoSold  YrSold SaleType SaleCondition  SalePrice
# 1453          2006       7    2006       WD       Abnorml      84500
# 216           2004       4    2008       WD        Normal     210000
# 1413          2006       9    2009      COD       Abnorml     257000

# %% [markdown]
# # Find reasonable object variables
# First I want to decide, which kind of object type variables I want to include! So I will go through the whole list...

# %%
##### Detect object type columns
train_objects = train.select_dtypes(include=['object'])
train_objects.sample(3)
# Out:
#      Street Alley LotShape LandContour Utilities Utilities LotConfig  \
# 627    Pave   NaN      Reg         Lvl    AllPub    AllPub    Inside
# 1373   Pave   NaN      Reg         Lvl    AllPub    AllPub    Inside
# 339    Pave   NaN      IR1         Lvl    AllPub    AllPub    Inside
#
#      LandSlope Condition1 Condition2 SaleType SaleCondition
# 627        Gtl       Norm       Norm       WD        Normal
# 1373       Gtl       Norm       Norm       WD        Normal
# 339        Gtl      Feedr       Norm       WD        Normal

# %% [markdown]
# Figure out which entries have null values!

# %%
object_nas = train_objects.isnull().sum()*100/len(train_objects)
object_nas[object_nas != 0]
# Out:
# Alley    93.767123
# dtype: float64

# %% [markdown]
# Set Alleys with Nas to no, since there is no alley!

# %%
train.Alley = train["Alley"].fillna("NoAlley")

# %% [markdown]
# Search for other missing values

# %%
object_nas = train.isnull().sum()*100/len(train)
object_nas[object_nas != 0]
# Out:
# LotFrontage    17.739726
# dtype: float64

# %% [markdown]
# Since only 17% of values are missing, do imputation with average LotFrontage.

# %%
my_imputer = Imputer()
train["LotFrontage"] = my_imputer.fit_transform(train[["LotFrontage"]]).ravel()
train.sample(5)
# Out:
#       LotFrontage  LotArea Street  Alley LotShape LandContour Utilities  \
# 968     50.000000     5925   Pave      0      Reg         Lvl    AllPub
# 330     70.049958    10624   Pave      0      IR1         Lvl    AllPub
# 1047    57.000000     9245   Pave      0      IR2         Lvl    AllPub
# 527     67.000000    14948   Pave      0      IR1         Lvl    AllPub
# 509     80.000000     9600   Pave      0      Reg         Lvl    AllPub
#
#      Utilities LotConfig LandSlope Condition1 Condition2  YearBuilt  \
# 968     AllPub    Inside       Gtl       Norm       Norm       1910
# 330     AllPub    Inside       Gtl       Norm       Norm       1964
# 1047    AllPub    Inside       Gtl       Norm       Norm       1994
# 527     AllPub    Inside       Gtl       Norm       Norm       2008
# 509     AllPub    Corner       Gtl       Norm       Norm       1959
#
#       YearRemodAdd  MoSold  YrSold SaleType SaleCondition  SalePrice
# 968           1950       5    2009       WD       Abnorml      37900
# 330           1964      11    2007       WD        Normal     119000
# 1047          1995       2    2008       WD        Normal     145000
# 527           2008      11    2008      New       Partial     446261
# 509           1959       7    2009       WD        Normal     124500

# %%
object_nas = train.isnull().sum()*100/len(train)
object_nas[object_nas != 0]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Make Hot-Encoding for objects

# %%
train_hot = pd.get_dummies(train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     398                 result = np.empty(len(values), dtype=object)
# --> 399                 result[:] = values
#     400             except ValueError:
#
# ValueError: could not broadcast input array from shape (1460,2) into shape (1460)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-61decff94616> in <module>()
# ----> 1 train_hot = pd.get_dummies(train)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1208             dummy = _get_dummies_1d(data[col], prefix=pre, prefix_sep=sep,
#    1209                                     dummy_na=dummy_na, sparse=sparse,
# -> 1210                                     drop_first=drop_first)
#    1211             with_dummies.append(dummy)
#    1212         result = concat(with_dummies, axis=1)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first)
#    1220                     sparse=False, drop_first=False):
#    1221     # Series avoids inconsistent NaN handling
# -> 1222     codes, levels = _factorize_from_iterable(Series(data))
#    1223
#    1224     def get_empty_Frame(data, sparse):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3275             raise Exception('Data must be 1-dimensional')
#    3276         else:
# -> 3277             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    3278
#    3279     # This is to prevent mixed-type Series getting all casted to
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     400             except ValueError:
#     401                 # we have a list-of-list
# --> 402                 result[:] = [tuple(x) for x in values]
#     403
#     404     return result
#
# ValueError: cannot copy sequence with size 2 to array axis with dimension 1460

# %%
pd.get_dummies(train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     398                 result = np.empty(len(values), dtype=object)
# --> 399                 result[:] = values
#     400             except ValueError:
#
# ValueError: could not broadcast input array from shape (1460,2) into shape (1460)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6fa84e9dd2e1> in <module>()
# ----> 1 pd.get_dummies(train)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1208             dummy = _get_dummies_1d(data[col], prefix=pre, prefix_sep=sep,
#    1209                                     dummy_na=dummy_na, sparse=sparse,
# -> 1210                                     drop_first=drop_first)
#    1211             with_dummies.append(dummy)
#    1212         result = concat(with_dummies, axis=1)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first)
#    1220                     sparse=False, drop_first=False):
#    1221     # Series avoids inconsistent NaN handling
# -> 1222     codes, levels = _factorize_from_iterable(Series(data))
#    1223
#    1224     def get_empty_Frame(data, sparse):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3275             raise Exception('Data must be 1-dimensional')
#    3276         else:
# -> 3277             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    3278
#    3279     # This is to prevent mixed-type Series getting all casted to
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     400             except ValueError:
#     401                 # we have a list-of-list
# --> 402                 result[:] = [tuple(x) for x in values]
#     403
#     404     return result
#
# ValueError: cannot copy sequence with size 2 to array axis with dimension 1460

# %%
train.sample(3)
# Out:
#       LotFrontage  LotArea Street  Alley LotShape LandContour Utilities  \
# 623           NaN     2117   Pave      0      Reg         Lvl    AllPub
# 650          65.0     8125   Pave      0      Reg         Lvl    AllPub
# 1330         85.0    10000   Pave      0      Reg         Lvl    AllPub
#
#      Utilities LotConfig LandSlope Condition1 Condition2  YearBuilt  \
# 623     AllPub    Inside       Gtl       Norm       Norm       2000
# 650     AllPub    Inside       Gtl       Norm       Norm       2007
# 1330    AllPub    Inside       Gtl       Norm       Norm       2006
#
#       YearRemodAdd  MoSold  YrSold SaleType SaleCondition  SalePrice
# 623           2000       6    2007       WD        Normal     168500
# 650           2007       5    2008       WD        Normal     205950
# 1330          2006      12    2007       WD        Normal     227000

# %%
cols_with_missing = [col for col in train_data.columns 
                                 if train_data[col].isnull().any()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-deb657b95d86> in <module>()
# ----> 1 cols_with_missing = [col for col in train_data.columns
#       2                                  if train_data[col].isnull().any()]
#
# NameError: name 'train_data' is not defined
